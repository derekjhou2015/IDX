# %%
#derek hou 4/9

import pandas as pd

#listings
listing1 = pd.read_csv("data/CRMLSListing202401.csv")
listing2 = pd.read_csv("data/CRMLSListing202402.csv")
listing3 = pd.read_csv("data/CRMLSListing202403.csv")
listing4 = pd.read_csv("data/CRMLSListing202404.csv")
listing5 = pd.read_csv("data/CRMLSListing202405.csv")
listing6 = pd.read_csv("data/CRMLSListing202406.csv")
listing7 = pd.read_csv("data/CRMLSListing202407.csv")
listing8 = pd.read_csv("data/CRMLSListing202408.csv")
listing9 = pd.read_csv("data/CRMLSListing202409.csv")
listing10 = pd.read_csv("data/CRMLSListing202410.csv")
listing11 = pd.read_csv("data/CRMLSListing202411.csv")
listing12 = pd.read_csv("data/CRMLSListing202501.csv")
listing13 = pd.read_csv("data/CRMLSListing202502.csv")
listing14 = pd.read_csv("data/CRMLSListing202503.csv")
listing15 = pd.read_csv("data/CRMLSListing202504.csv")
listing16 = pd.read_csv("data/CRMLSListing202505.csv")
listing17 = pd.read_csv("data/CRMLSListing202506.csv")  
listing18 = pd.read_csv("data/CRMLSListing202507.csv")
listing19 = pd.read_csv("data/CRMLSListing202508.csv")
listing20 = pd.read_csv("data/CRMLSListing202509.csv")
listing21 = pd.read_csv("data/CRMLSListing202510.csv")
listing22 = pd.read_csv("data/CRMLSListing202511.csv")
listing23 = pd.read_csv("data/CRMLSListing202512.csv")
listing24 = pd.read_csv("data/CRMLSListing202601.csv")

#length of listings before concat
raw_listings_total = len(listing1) + len(listing2) + len(listing3) + len(listing4) + len(listing5) + len(listing6) + len(listing7) + len(listing8) + len(listing9) + len(listing10) + len(listing11) + len(listing12) + len(listing13) + len(listing14) + len(listing15) + len(listing16) + len(listing17) + len(listing18) + len(listing19) + len(listing20) + len(listing21) + len(listing22) + len(listing23) + len(listing24)
print(f"Total Listing rows before concat: {raw_listings_total}")

#length of listings after concat
listings = pd.concat([listing1, listing2, listing3, listing4, listing5, listing6, listing7, listing8, listing9, listing10, listing11, listing12, listing13, listing14, listing15, listing16, listing17, listing18, listing19, listing20, listing21, listing22, listing23, listing24], ignore_index=True)
print(f"Total Listing rows after concat: {len(listings)}")

#length of listing rows after residential filter
listings_res = listings[listings['PropertyType'] == 'Residential']
print(f"Total Listing rows after Residential filter: {len(listings_res)}")

#save to a new combined csv file
listings_res.to_csv("combined_listings_residential.csv", index=False)

#solds
sold1 = pd.read_csv("data/CRMLSSold202401.csv")
sold2 = pd.read_csv("data/CRMLSSold202402.csv")
sold3 = pd.read_csv("data/CRMLSSold202403.csv")
sold4 = pd.read_csv("data/CRMLSSold202404.csv")
sold5 = pd.read_csv("data/CRMLSSold202405.csv")
sold6 = pd.read_csv("data/CRMLSSold202406.csv")
sold7 = pd.read_csv("data/CRMLSSold202407.csv")
sold8 = pd.read_csv("data/CRMLSSold202408.csv")
sold9 = pd.read_csv("data/CRMLSSold202409.csv")
sold10 = pd.read_csv("data/CRMLSSold202410.csv")
sold11 = pd.read_csv("data/CRMLSSold202411.csv")
sold12 = pd.read_csv("data/CRMLSSold202501.csv")
sold13 = pd.read_csv("data/CRMLSSold202502.csv")
sold14 = pd.read_csv("data/CRMLSSold202503.csv")
sold15 = pd.read_csv("data/CRMLSSold202504.csv")
sold16 = pd.read_csv("data/CRMLSSold202505.csv")
sold17 = pd.read_csv("data/CRMLSSold202506.csv")  
sold18 = pd.read_csv("data/CRMLSSold202507.csv")
sold19 = pd.read_csv("data/CRMLSSold202508.csv")
sold20 = pd.read_csv("data/CRMLSSold202509.csv")
sold21 = pd.read_csv("data/CRMLSSold202510.csv")
sold22 = pd.read_csv("data/CRMLSSold202511.csv")
sold23 = pd.read_csv("data/CRMLSSold202512.csv")
sold24 = pd.read_csv("data/CRMLSSold202601.csv")

#length of solds before concat
raw_solds_total = len(sold1) + len(sold2) + len(sold3) + len(sold4) + len(sold5) + len(sold6) + len(sold7) + len(sold8) + len(sold9) + len(sold10) + len(sold11) + len(sold12) + len(sold13) + len(sold14) + len(sold15) + len(sold16) + len(sold17) + len(sold18) + len(sold19) + len(sold20) + len(sold21) + len(sold22) + len(sold23) + len(sold24)
print(f"Total Sold rows before concat: {raw_solds_total}")

#length of solds after concat
solds = pd.concat([sold1, sold2, sold3, sold4, sold5, sold6, sold7, sold8, sold9, sold10, sold11, sold12, sold13, sold14, sold15, sold16, sold17, sold18, sold19, sold20, sold21, sold22, sold23, sold24], ignore_index=True)
print(f"Total Sold rows after concat: {len(solds)}")

#length of solds rows after residential filter
solds_res = solds[solds['PropertyType'] == 'Residential']
print(f"Total Sold rows after Residential filter: {len(solds_res)}")

solds_res.to_csv("combined_solds_residential.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 import pandas as pd
#       5 #listings
# ----> 6 listing1 = pd.read_csv("data/CRMLSListing202401.csv")
#       7 listing2 = pd.read_csv("data/CRMLSListing202402.csv")
#       8 listing3 = pd.read_csv("data/CRMLSListing202403.csv")
#
# ...
